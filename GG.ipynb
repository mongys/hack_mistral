# %%
! pip install -U langchain openai chromadb langchain-experimental
# Out:
# Requirement already satisfied: langchain in /var/.venv/lib/python3.11/site-packages (0.2.1)
# Collecting openai
#   Downloading openai-1.30.5-py3-none-any.whl.metadata (21 kB)
# Collecting chromadb
#   Downloading chromadb-0.5.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.0.59-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /var/.venv/lib/python3.11/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /var/.venv/lib/python3.11/site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /var/.venv/lib/python3.11/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in /var/.venv/lib/python3.11/site-packages (from langchain) (0.2.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /var/.venv/lib/python3.11/site-packages (from langchain) (0.2.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /var/.venv/lib/python3.11/site-packages (from langchain) (0.1.67)
# Requirement already satisfied: numpy<2,>=1 in /var/.venv/lib/python3.11/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /var/.venv/lib/python3.11/site-packages (from langchain) (2.7.2)
# Requirement already satisfied: requests<3,>=2 in /var/.venv/lib/python3.11/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /var/.venv/lib/python3.11/site-packages (from langchain) (8.3.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /var/.venv/lib/python3.11/site-packages (from openai) (4.4.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /var/.venv/lib/python3.11/site-packages (from openai) (0.27.0)
# Requirement already satisfied: sniffio in /var/.venv/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /var/.venv/lib/python3.11/site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /var/.venv/lib/python3.11/site-packages (from openai) (4.12.0)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Downloading chroma_hnswlib-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.111.0-py3-none-any.whl.metadata (25 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.30.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.5.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: onnxruntime>=1.14.1 in /var/.venv/lib/python3.11/site-packages (from chromadb) (1.18.0)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.25.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.46b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.25.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /var/.venv/lib/python3.11/site-packages (from chromadb) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 910.5 kB/s eta 0:00:00 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /var/.venv/lib/python3.11/site-packages (from chromadb) (1.64.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.1.3-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-4.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: orjson>=3.9.12 in /var/.venv/lib/python3.11/site-packages (from chromadb) (3.10.3)
# Collecting langchain-community<0.3,>=0.2 (from langchain-experimental)
#   Downloading langchain_community-0.2.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /var/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /var/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /var/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /var/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /var/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /var/.venv/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: packaging>=19.1 in /var/.venv/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (23.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting fastapi-cli>=0.0.2 (from fastapi>=0.95.2->chromadb)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: jinja2>=2.11.2 in /var/.venv/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in /var/.venv/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb) (0.0.9)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi>=0.95.2->chromadb)
#   Downloading ujson-5.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Collecting email_validator>=2.0.0 (from fastapi>=0.95.2->chromadb)
#   Downloading email_validator-2.1.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: certifi in /var/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /var/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /var/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /var/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /var/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /var/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.29.0)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in /var/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /var/.venv/lib/python3.11/site-packages (from langchain-community<0.3,>=0.2->langchain-experimental) (0.6.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /var/.venv/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (1.33)
# Requirement already satisfied: coloredlogs in /var/.venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /var/.venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /var/.venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: sympy in /var/.venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12.1)
# Requirement already satisfied: deprecated>=1.2.6 in /var/.venv/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Collecting importlib-metadata<=7.1,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /var/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-proto==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-asgi==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.46b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.46b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-util-http==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.46b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: setuptools>=16.0 in /var/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (66.1.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /var/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: backoff>=1.10.0 in /var/.venv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /var/.venv/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in /var/.venv/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (2.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /var/.venv/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /var/.venv/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /var/.venv/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb) (0.23.2)
# Requirement already satisfied: click>=8.0.0 in /var/.venv/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer>=0.9.0->chromadb)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-12.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /var/.venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3,>=0.2->langchain-experimental) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /var/.venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3,>=0.2->langchain-experimental) (0.9.0)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /var/.venv/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /var/.venv/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /var/.venv/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /var/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /var/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.5.0)
# Collecting zipp>=0.5 (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Downloading zipp-3.19.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /var/.venv/lib/python3.11/site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in /var/.venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain) (2.4)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer>=0.9.0->chromadb)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /var/.venv/lib/python3.11/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.18.0)
# Requirement already satisfied: humanfriendly>=9.1 in /var/.venv/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /var/.venv/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /var/.venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /var/.venv/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3,>=0.2->langchain-experimental) (1.0.0)
# Downloading openai-1.30.5-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 3.5 MB/s eta 0:00:00:00:01
# Downloading chromadb-0.5.0-py3-none-any.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.8/526.8 kB 5.5 MB/s eta 0:00:00:00:01
# Downloading chroma_hnswlib-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 10.7 MB/s eta 0:00:0000:0100:01
# Downloading langchain_experimental-0.0.59-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.5/199.5 kB 2.8 MB/s eta 0:00:00:00:01
# Downloading bcrypt-4.1.3-cp39-abi3-manylinux_2_28_x86_64.whl (283 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 3.9 MB/s eta 0:00:00ta 0:00:01
# Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 1.5 MB/s eta 0:00:00ta 0:00:01
# Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 8.9 MB/s eta 0:00:00:00:0100:01
# Downloading langchain_community-0.2.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.8 MB/s eta 0:00:00:00:0100:01
# Downloading mmh3-4.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 1.4 MB/s eta 0:00:00ta 0:00:01
# Downloading opentelemetry_api-1.25.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 765.9 kB/s eta 0:00:00 0:00:01
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.25.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 726.7 kB/s eta 0:00:000:01
# Downloading opentelemetry_instrumentation_fastapi-0.46b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.46b0-py3-none-any.whl (29 kB)
# Downloading opentelemetry_instrumentation_asgi-0.46b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 1.8 MB/s eta 0:00:00ta 0:00:01
# Downloading opentelemetry_util_http-0.46b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.25.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 396.1 kB/s eta 0:00:00a 0:00:01
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 133.5 kB/s eta 0:00:000:01
# Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 252.8 kB/s eta 0:00:00 0:00:01
# Downloading uvicorn-0.30.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 190.9 kB/s eta 0:00:000:01
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Downloading email_validator-2.1.1-py3-none-any.whl (30 kB)
# Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Downloading httptools-0.6.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.5/318.5 kB 1.2 MB/s eta 0:00:00:00:01
# Downloading importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 435.5 kB/s eta 0:00:00a 0:00:01
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 1.9 MB/s eta 0:00:00:00:01
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 2.9 MB/s eta 0:00:00
# Downloading ujson-5.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 541.3 kB/s eta 0:00:00 0:00:01
# Downloading uvloop-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 10.5 MB/s eta 0:00:0000:0100:01
# Downloading watchfiles-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.0 MB/s eta 0:00:00:00:01
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 784.3 kB/s eta 0:00:00 0:00:01
# Downloading websockets-12.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.9/130.9 kB 1.9 MB/s eta 0:00:00ta 0:00:01
# Downloading pyproject_hooks-1.1.0-py3-none-any.whl (9.2 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 5.5 MB/s eta 0:00:00:00:01
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 1.6 MB/s eta 0:00:00ta 0:00:01
# Downloading zipp-3.19.1-py3-none-any.whl (9.0 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53724 sha256=f01c6021522c058a5b265b52d0a9f9453709b096cbc33281e774f9dbc00670ef
#   Stored in directory: /root/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, zipp, websockets, websocket-client, uvloop, uvicorn, ujson, shellingham, python-dotenv, pyproject_hooks, overrides, opentelemetry-util-http, opentelemetry-proto, oauthlib, mdurl, importlib-resources, httptools, dnspython, distro, chroma-hnswlib, bcrypt, asgiref, watchfiles, starlette, requests-oauthlib, posthog, opentelemetry-exporter-otlp-proto-common, markdown-it-py, importlib-metadata, email_validator, build, rich, opentelemetry-api, openai, kubernetes, typer, opentelemetry-semantic-conventions, opentelemetry-instrumentation, opentelemetry-sdk, opentelemetry-instrumentation-asgi, fastapi-cli, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, fastapi, langchain-community, chromadb, langchain-experimental
# Successfully installed asgiref-3.8.1 bcrypt-4.1.3 build-1.2.1 chroma-hnswlib-0.7.3 chromadb-0.5.0 distro-1.9.0 dnspython-2.6.1 email_validator-2.1.1 fastapi-0.111.0 fastapi-cli-0.0.4 httptools-0.6.1 importlib-metadata-7.1.0 importlib-resources-6.4.0 kubernetes-29.0.0 langchain-community-0.2.1 langchain-experimental-0.0.59 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-4.1.0 monotonic-1.6 oauthlib-3.2.2 openai-1.30.5 opentelemetry-api-1.25.0 opentelemetry-exporter-otlp-proto-common-1.25.0 opentelemetry-exporter-otlp-proto-grpc-1.25.0 opentelemetry-instrumentation-0.46b0 opentelemetry-instrumentation-asgi-0.46b0 opentelemetry-instrumentation-fastapi-0.46b0 opentelemetry-proto-1.25.0 opentelemetry-sdk-1.25.0 opentelemetry-semantic-conventions-0.46b0 opentelemetry-util-http-0.46b0 overrides-7.7.0 posthog-3.5.0 pypika-0.48.9 pyproject_hooks-1.1.0 python-dotenv-1.0.1 requests-oauthlib-2.0.0 rich-13.7.1 shellingham-1.5.4 starlette-0.37.2 typer-0.12.3 ujson-5.10.0 uvicorn-0.30.0 uvloop-0.19.0 watchfiles-0.22.0 websocket-client-1.8.0 websockets-12.0 zipp-3.19.1

# %%
! pip install "unstructured[all-docs]==0.10.19" pillow pydantic lxml pillow matplotlib tiktoken open_clip_torch torch
# Out:
# Collecting unstructured==0.10.19 (from unstructured[all-docs]==0.10.19)
#   Downloading unstructured-0.10.19-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pillow in /var/.venv/lib/python3.11/site-packages (10.3.0)
# Requirement already satisfied: pydantic in /var/.venv/lib/python3.11/site-packages (2.7.2)
# Requirement already satisfied: lxml in /var/.venv/lib/python3.11/site-packages (5.2.2)
# Requirement already satisfied: matplotlib in /var/.venv/lib/python3.11/site-packages (3.9.0)
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting open_clip_torch
#   Downloading open_clip_torch-2.24.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: torch in /var/.venv/lib/python3.11/site-packages (2.3.0)
# Requirement already satisfied: chardet in /var/.venv/lib/python3.11/site-packages (from unstructured==0.10.19->unstructured[all-docs]==0.10.19) (5.2.0)
# Requirement already satisfied: filetype in /var/.venv/lib/python3.11/site-packages (from unstructured==0.10.19->unstructured[all-docs]==0.10.19) (1.2.0)
# Requirement already satisfied: python-magic in /var/.venv/lib/python3.11/site-packages (from unstructured==0.10.19->unstructured[all-docs]==0.10.19) (0.4.27)
# Requirement already satisfied: nltk in /var/.venv/lib/python3.11/site-packages (from unstructured==0.10.19->unstructured[all-docs]==0.10.19) (3.8.1)
# Requirement already satisfied: tabulate in /var/.venv/lib/python3.11/site-packages (from unstructured==0.10.19->unstructured[all-docs]==0.10.19) (0.9.0)
# Requirement already satisfied: requests in /var/.venv/lib/python3.11/site-packages (from unstructured==0.10.19->unstructured[all-docs]==0.10.19) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /var/.venv/lib/python3.11/site-packages (from unstructured==0.10.19->unstructured[all-docs]==0.10.19) (4.12.3)
# Requirement already satisfied: emoji in /var/.venv/lib/python3.11/site-packages (from unstructured==0.10.19->unstructured[all-docs]==0.10.19) (2.12.1)
# Requirement already satisfied: dataclasses-json in /var/.venv/lib/python3.11/site-packages (from unstructured==0.10.19->unstructured[all-docs]==0.10.19) (0.6.6)
# Requirement already satisfied: python-iso639 in /var/.venv/lib/python3.11/site-packages (from unstructured==0.10.19->unstructured[all-docs]==0.10.19) (2024.4.27)
# Requirement already satisfied: langdetect in /var/.venv/lib/python3.11/site-packages (from unstructured==0.10.19->unstructured[all-docs]==0.10.19) (1.0.9)
# Requirement already satisfied: numpy in /var/.venv/lib/python3.11/site-packages (from unstructured==0.10.19->unstructured[all-docs]==0.10.19) (1.26.4)
# Requirement already satisfied: msg-parser in /var/.venv/lib/python3.11/site-packages (from unstructured[all-docs]==0.10.19) (1.2.0)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /var/.venv/lib/python3.11/site-packages (from unstructured[all-docs]==0.10.19) (0.3.12)
# Requirement already satisfied: openpyxl in /var/.venv/lib/python3.11/site-packages (from unstructured[all-docs]==0.10.19) (3.1.3)
# Requirement already satisfied: pandas in /var/.venv/lib/python3.11/site-packages (from unstructured[all-docs]==0.10.19) (2.2.2)
# Requirement already satisfied: pdf2image in /var/.venv/lib/python3.11/site-packages (from unstructured[all-docs]==0.10.19) (1.17.0)
# Requirement already satisfied: pdfminer.six in /var/.venv/lib/python3.11/site-packages (from unstructured[all-docs]==0.10.19) (20231228)
# Collecting python-pptx<=0.6.21 (from unstructured[all-docs]==0.10.19)
#   Downloading python-pptx-0.6.21.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 9.7 MB/s eta 0:00:00:00:010:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pypandoc in /var/.venv/lib/python3.11/site-packages (from unstructured[all-docs]==0.10.19) (1.13)
# Requirement already satisfied: xlrd in /var/.venv/lib/python3.11/site-packages (from unstructured[all-docs]==0.10.19) (2.0.1)
# Requirement already satisfied: python-docx in /var/.venv/lib/python3.11/site-packages (from unstructured[all-docs]==0.10.19) (1.1.2)
# Collecting unstructured-inference==0.6.6 (from unstructured[all-docs]==0.10.19)
#   Downloading unstructured_inference-0.6.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting ebooklib (from unstructured[all-docs]==0.10.19)
#   Downloading EbookLib-0.18.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.5/115.5 kB 2.0 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: markdown in /var/.venv/lib/python3.11/site-packages (from unstructured[all-docs]==0.10.19) (3.6)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /var/.venv/lib/python3.11/site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (0.3.4)
# Requirement already satisfied: python-multipart in /var/.venv/lib/python3.11/site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (0.0.9)
# Requirement already satisfied: huggingface-hub in /var/.venv/lib/python3.11/site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (0.23.2)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /var/.venv/lib/python3.11/site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (4.9.0.80)
# Collecting onnx==1.14.1 (from unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19)
#   Downloading onnx-1.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: onnxruntime in /var/.venv/lib/python3.11/site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (1.18.0)
# Requirement already satisfied: transformers>=4.25.1 in /var/.venv/lib/python3.11/site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (4.41.2)
# Requirement already satisfied: rapidfuzz in /var/.venv/lib/python3.11/site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (3.9.3)
# Requirement already satisfied: protobuf>=3.20.2 in /var/.venv/lib/python3.11/site-packages (from onnx==1.14.1->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (4.25.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /var/.venv/lib/python3.11/site-packages (from onnx==1.14.1->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (4.12.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /var/.venv/lib/python3.11/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in /var/.venv/lib/python3.11/site-packages (from pydantic) (2.18.3)
# Requirement already satisfied: contourpy>=1.0.1 in /var/.venv/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /var/.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /var/.venv/lib/python3.11/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /var/.venv/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /var/.venv/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /var/.venv/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /var/.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: regex>=2022.1.18 in /var/.venv/lib/python3.11/site-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: torchvision in /var/.venv/lib/python3.11/site-packages (from open_clip_torch) (0.18.0)
# Collecting ftfy (from open_clip_torch)
#   Downloading ftfy-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: tqdm in /var/.venv/lib/python3.11/site-packages (from open_clip_torch) (4.66.4)
# Collecting sentencepiece (from open_clip_torch)
#   Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: timm in /var/.venv/lib/python3.11/site-packages (from open_clip_torch) (1.0.3)
# Requirement already satisfied: filelock in /var/.venv/lib/python3.11/site-packages (from torch) (3.14.0)
# Requirement already satisfied: sympy in /var/.venv/lib/python3.11/site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /var/.venv/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /var/.venv/lib/python3.11/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /var/.venv/lib/python3.11/site-packages (from torch) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /var/.venv/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /var/.venv/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /var/.venv/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /var/.venv/lib/python3.11/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /var/.venv/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /var/.venv/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /var/.venv/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /var/.venv/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /var/.venv/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /var/.venv/lib/python3.11/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /var/.venv/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /var/.venv/lib/python3.11/site-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /var/.venv/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.40)
# Requirement already satisfied: six>=1.5 in /var/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /var/.venv/lib/python3.11/site-packages (from python-pptx<=0.6.21->unstructured[all-docs]==0.10.19) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /var/.venv/lib/python3.11/site-packages (from requests->unstructured==0.10.19->unstructured[all-docs]==0.10.19) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /var/.venv/lib/python3.11/site-packages (from requests->unstructured==0.10.19->unstructured[all-docs]==0.10.19) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /var/.venv/lib/python3.11/site-packages (from requests->unstructured==0.10.19->unstructured[all-docs]==0.10.19) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /var/.venv/lib/python3.11/site-packages (from requests->unstructured==0.10.19->unstructured[all-docs]==0.10.19) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /var/.venv/lib/python3.11/site-packages (from beautifulsoup4->unstructured==0.10.19->unstructured[all-docs]==0.10.19) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /var/.venv/lib/python3.11/site-packages (from dataclasses-json->unstructured==0.10.19->unstructured[all-docs]==0.10.19) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /var/.venv/lib/python3.11/site-packages (from dataclasses-json->unstructured==0.10.19->unstructured[all-docs]==0.10.19) (0.9.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /var/.venv/lib/python3.11/site-packages (from ftfy->open_clip_torch) (0.2.13)
# Requirement already satisfied: pyyaml>=5.1 in /var/.venv/lib/python3.11/site-packages (from huggingface-hub->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (6.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /var/.venv/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: olefile>=0.46 in /var/.venv/lib/python3.11/site-packages (from msg-parser->unstructured[all-docs]==0.10.19) (0.47)
# Requirement already satisfied: click in /var/.venv/lib/python3.11/site-packages (from nltk->unstructured==0.10.19->unstructured[all-docs]==0.10.19) (8.1.7)
# Requirement already satisfied: joblib in /var/.venv/lib/python3.11/site-packages (from nltk->unstructured==0.10.19->unstructured[all-docs]==0.10.19) (1.4.2)
# Requirement already satisfied: et-xmlfile in /var/.venv/lib/python3.11/site-packages (from openpyxl->unstructured[all-docs]==0.10.19) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /var/.venv/lib/python3.11/site-packages (from pandas->unstructured[all-docs]==0.10.19) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /var/.venv/lib/python3.11/site-packages (from pandas->unstructured[all-docs]==0.10.19) (2024.1)
# Requirement already satisfied: cryptography>=36.0.0 in /var/.venv/lib/python3.11/site-packages (from pdfminer.six->unstructured[all-docs]==0.10.19) (42.0.7)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /var/.venv/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: safetensors in /var/.venv/lib/python3.11/site-packages (from timm->open_clip_torch) (0.4.3)
# Requirement already satisfied: cffi>=1.12 in /var/.venv/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]==0.10.19) (1.16.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /var/.venv/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (0.19.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /var/.venv/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured==0.10.19->unstructured[all-docs]==0.10.19) (1.0.0)
# Requirement already satisfied: scipy in /var/.venv/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (1.13.1)
# Requirement already satisfied: iopath in /var/.venv/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (0.1.10)
# Requirement already satisfied: pdfplumber in /var/.venv/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (0.11.0)
# Requirement already satisfied: effdet in /var/.venv/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (0.4.1)
# Requirement already satisfied: pytesseract in /var/.venv/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (0.3.10)
# Requirement already satisfied: coloredlogs in /var/.venv/lib/python3.11/site-packages (from onnxruntime->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (15.0.1)
# Requirement already satisfied: flatbuffers in /var/.venv/lib/python3.11/site-packages (from onnxruntime->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (24.3.25)
# Requirement already satisfied: pycparser in /var/.venv/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]==0.10.19) (2.22)
# Requirement already satisfied: humanfriendly>=9.1 in /var/.venv/lib/python3.11/site-packages (from coloredlogs->onnxruntime->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (10.0)
# Requirement already satisfied: pycocotools>=2.0.2 in /var/.venv/lib/python3.11/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (2.0.7)
# Requirement already satisfied: omegaconf>=2.0 in /var/.venv/lib/python3.11/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (2.3.0)
# Requirement already satisfied: portalocker in /var/.venv/lib/python3.11/site-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (2.8.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in /var/.venv/lib/python3.11/site-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (4.30.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /var/.venv/lib/python3.11/site-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]==0.10.19) (4.9.3)
# Downloading unstructured-0.10.19-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.6 MB/s eta 0:00:00:00:0100:01
# Downloading unstructured_inference-0.6.6-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 1.7 MB/s eta 0:00:00
# Downloading onnx-1.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 9.8 MB/s eta 0:00:00:00:0100:01
# Downloading tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.6 MB/s eta 0:00:00:00:01
# Downloading open_clip_torch-2.24.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 10.0 MB/s eta 0:00:0000:0100:01
# Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 822.6 kB/s eta 0:00:00 0:00:01
# Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.4 MB/s eta 0:00:00:00:0100:01
# Building wheels for collected packages: python-pptx, ebooklib
#   Building wheel for python-pptx (pyproject.toml) ... done
#   Created wheel for python-pptx: filename=python_pptx-0.6.21-py3-none-any.whl size=470931 sha256=c1b9ca34b45a3dc0a58458e568005a0ba0ecef4f5b4bd6495e199ad10ea4a84f
#   Stored in directory: /root/.cache/pip/wheels/f4/c7/af/d1d91f3decfaa7621033f30b69a29bf0b1206005663d233e7a
#   Building wheel for ebooklib (pyproject.toml) ... done
#   Created wheel for ebooklib: filename=EbookLib-0.18-py3-none-any.whl size=38778 sha256=77743c75cfc4cf25e0b62afe89626c222c58a4baa17e6f57eaedbf36a79f2dec
#   Stored in directory: /root/.cache/pip/wheels/65/2b/63/68307c736d5a2fafeebe9df3e5eccacfe892204ce1fd31a03c
# Successfully built python-pptx ebooklib
# Installing collected packages: sentencepiece, python-pptx, onnx, ftfy, ebooklib, tiktoken, unstructured, open_clip_torch, unstructured-inference
#   Attempting uninstall: python-pptx
#     Found existing installation: python-pptx 0.6.23
#     Uninstalling python-pptx-0.6.23:
#       Successfully uninstalled python-pptx-0.6.23
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.16.1
#     Uninstalling onnx-1.16.1:
#       Successfully uninstalled onnx-1.16.1
#   Attempting uninstall: unstructured
#     Found existing installation: unstructured 0.14.3
#     Uninstalling unstructured-0.14.3:
#       Successfully uninstalled unstructured-0.14.3
#   Attempting uninstall: unstructured-inference
#     Found existing installation: unstructured-inference 0.7.33
#     Uninstalling unstructured-inference-0.7.33:
#       Successfully uninstalled unstructured-inference-0.7.33
# Successfully installed ebooklib-0.18 ftfy-6.2.0 onnx-1.14.1 open_clip_torch-2.24.0 python-pptx-0.6.21 sentencepiece-0.2.0 tiktoken-0.7.0 unstructured-0.10.19 unstructured-inference-0.6.6

# %%
from unstructured.partition.pdf import partition_pdf
import os
os.putenv('TESSDATA_PREFIX','/var/lib/dpkg/info/tesseract-ocr-rus.list')
path="/var/mistral_test/"

# Extract images, tables, and chunk text
raw_pdf_elements = partition_pdf(
    filename=path + "Summary_MICEX-RTS_FS_4Q2022_RUS.pdf",
    extract_images_in_pdf=True,
    infer_table_structure=True,
    ocr_languages="rus+eng",
    chunking_strategy="by_title",
    max_characters=4000,
    new_after_n_chars=3800,
    combine_text_under_n_chars=2000,
    image_output_dir_path=path+"image",
)

# Categorize by type
tables = []
texts = []
for element in raw_pdf_elements:
    if "unstructured.documents.elements.Table" in str(type(element)):
        tables.append(str(element))
    elif "unstructured.documents.elements.CompositeElement" in str(type(element)):
        texts.append(str(element))
# Out:
# WARNING:unstructured:The ocr_languages kwarg will be deprecated in a future version of unstructured. Please use languages instead.

# %%
from langchain_experimental.open_clip import OpenCLIPEmbeddings
from langchain_community.vectorstores import Chroma

# Create chroma w/ multi-modal embeddings
multimodal_embd = Chroma(
    collection_name="multimodal_embd", embedding_function=OpenCLIPEmbeddings()
)

# Get image URIs
image_uris = sorted(
    [
        os.path.join(path+"image/", image_name)
        for image_name in os.listdir(path+"image/")
        if image_name.endswith(".jpg")
    ]
)

# Add images and documents
if image_uris:
    multimodal_embd.add_images(uris=image_uris)
if texts:
    multimodal_embd.add_texts(texts=texts)
if tables:
    multimodal_embd.add_texts(texts=tables)

# Make retriever
retriever_multimodal_embd = multimodal_embd.as_retriever()

# %%
import re
from operator import itemgetter
import base64
from langchain_core.runnables import RunnablePassthrough
from langchain_core.documents import Document
from langchain_core.runnables import RunnableLambda
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
import torch
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    AutoTokenizer,
)
from transformers import GenerationConfig

# %%
model_name = "/var/mistral_test/Mistral-7B-Instruct-v0.2"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
tokenizer.pad_token = tokenizer.unk_token
tokenizer.pad_token_id =  tokenizer.unk_token_id
tokenizer.padding_side = 'left'

compute_dtype = getattr(torch, "float16")
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}
)
#Configure the pad token in the model
model.config.pad_token_id = tokenizer.pad_token_id
# Out:
# Loading checkpoint shards: 100%|██████████| 3/3 [01:15<00:00, 25.07s/it]

# %%
def looks_like_base64(sb):
    """Check if the string looks like base64."""
    return re.match("^[A-Za-z0-9+/]+[=]{0,2}$", sb) is not None


def is_image_data(b64data):
    """Check if the base64 data is an image by looking at the start of the data."""
    image_signatures = {
        b"\xff\xd8\xff": "jpg",
        b"\x89\x50\x4e\x47\x0d\x0a\x1a\x0a": "png",
        b"\x47\x49\x46\x38": "gif",
        b"\x52\x49\x46\x46": "webp",
    }
    try:
        header = base64.b64decode(b64data)[:8]  # Decode and get the first 8 bytes
        for sig, format in image_signatures.items():
            if header.startswith(sig):
                return True
        return False
    except Exception:
        return False


def split_image_text_types(docs):
    """Split base64-encoded images and texts."""
    b64_images = []
    texts = []
    for doc in docs:
        # Check if the document is of type Document and extract page_content if so
        if isinstance(doc, Document):
            doc = doc.page_content
        if looks_like_base64(doc) and is_image_data(doc):
            b64_images.append(doc)
        else:
            texts.append(doc)
    return {"images": b64_images, "texts": texts}


def img_prompt_func(data_dict):
    # Joining the context texts into a single string
    formatted_texts = "\n".join(data_dict["context"]["texts"])
    messages = []

    # Adding image(s) to the messages if present
    if data_dict["context"]["images"]:
        image_message = {
            "type": "image_url",
            "image_url": {
                "url": f"data:image/jpeg;base64,{data_dict['context']['images'][0]}"
            },
        }
        messages.append(image_message)

    # Adding the text message for analysis
    text_message = {
        "type": "text",
        "text": (
            "Answer the question based only on the provided context, which can include text, tables, and image(s). "
            "If an image is provided, analyze it carefully to help answer the question.\n"
            f"User-provided question / keywords: {data_dict['question']}\n\n"
            "Text and / or tables:\n"
            f"{formatted_texts}"
        ),
    }
    messages.append(text_message)
    return [HumanMessage(content=messages)]


def multi_modal_rag_chain(retriever):
    """Multi-modal RAG chain"""

    # RAG pipeline
    chain = (
        {
            "context": retriever | RunnableLambda(split_image_text_types),
            "question": RunnablePassthrough(),
        }
        | RunnableLambda(img_prompt_func)
        | model
        | StrOutputParser()
    )

    return chain

# %%
chain_multimodal_embd = multi_modal_rag_chain(retriever_multimodal_embd)

# %%
import pandas as pd

eval_set = pd.read_excel(path + "вопросы-ответы.xlsx")
eval_set.head(3)
# Out:
#                                               Вопрос  \
# 0  Группа считает признаками дефолта следующие ви...
# 1                  Из чего состоят арендные платежи?
# 2  В каких случаях группа переоценивает обязатель...
#
#              Отчёт, из которого взят вопрос  \
# 0  Summary_MICEX-RTS_FS_4Q2022_RUS, стр. 19
# 1  Summary_MICEX-RTS_FS_4Q2022_RUS, стр. 27
# 2  Summary_MICEX-RTS_FS_4Q2022_RUS, стр. 27
#
#                                     Правильный ответ
# 0  контрагент признан несостоятельным (банкротом)...
# 1  (а) фиксированных платежей (включая по существ...
# 2  (а) при изменении срока аренды или изменении о...

# %%
import uuid
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Initialize the dataset
dataset_name = f"CPI Eval {str(uuid.uuid4())}"
dataset = []

# Assuming eval_set is a pandas DataFrame
for _, row in eval_set.iterrows():
    # Get Q, A
    q = row["Вопрос"]
    a = row["Правильный ответ"]
    source=row["Отчёт, из которого взят вопрос"]
    # Add the example to the dataset
    dataset.append({"question": q, "answer": a, "source": source})



def generate_response(prompt):
    try:
        inputs = tokenizer(prompt+"формулируй ответы только на русском", return_tensors="pt")
        outputs = model.generate(**inputs, max_new_tokens=150)
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        response = response[len(prompt):].strip()
        return response
    except Exception as e:
        print(f"Error generating response: {e}")
        return "Произошла ошибка при генерации ответа."

# Evaluate the model on the dataset
for example in dataset:
    question = example["question"]
    correct_answer = example["answer"]
    source=row["Отчёт, из которого взят вопрос"]
    generated_response = generate_response(question)
    print(f"Question: {question}")
    print(f"source: {source}")
    print(f"Correct Answer: {correct_answer}")
    print(f"Generated Response: {generated_response}")
    print("="*50)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# /var/.venv/lib/python3.11/site-packages/transformers/generation/utils.py:1659: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Question: Группа считает признаками дефолта следующие виды событий
# source: Summary_MICEX-RTS_FS_4Q2022_RUS, стр. 9
# Correct Answer: контрагент признан несостоятельным (банкротом);
# в суд подан иск третьего лица о признании контрагента несостоятельным (банкротом) и судом вынесено определение о принятии иска к производству;
# контрагент является устойчиво неплатежеспособным, т.е. не выполняет свои обязательства перед Группой в течение срока более 90 календарных дней;
# лицензия контрагента отозвана;
# было принято решение о ликвидации в отношении контрагента.
# Generated Response: формулируй ответы только на русском языке:
#
# 1. Отказ кредитора предоставлять новые кредиты клиенту.
# 2. Отказ кредитора продлевать срок по текущим кредитам.
# 3. Отказ кредитора погасить кредиты по сроку.
# 4. Отказ кредитора погасить кредиты по сниженным условиям.
# 5. Отказ кредитора погасить кредиты по причине несоответствия кредитоспособности клиента.
# 6. Отказ кредитора погасить кредиты по при
# ==================================================
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Question: Из чего состоят арендные платежи?
# source: Summary_MICEX-RTS_FS_4Q2022_RUS, стр. 9
# Correct Answer: (а) фиксированных платежей (включая по существу фиксированные платежи) за вычетом любых
# стимулирующих платежей;
# (б) переменных арендных платежей, зависящих от индекса или ставки, первоначально оцениваемых с
# использованием индекса или ставки на дату начала аренды;
# (в) сумм, которые, как ожидается, будут уплачены арендатором по гарантиям ликвидационной
# стоимости;
# (г) цены исполнения опциона на покупку, если имеется достаточная уверенность в том, что арендатор
# исполнит этот опцион; и
# (д) выплаты штрафов за прекращение аренды, если срок аренды отражает потенциальное исполнение
# арендатором опциона на прекращение аренды.
# Generated Response: формулируй ответы только на русском языке
#
# Арендные платежи состоят из трёх основных компонентов:
#
# 1. Арендная плата (rent): это ежемесячная плата, которую платёк (tenant) платит землепользователю (landlord) за использование недвижимого имущества.
# 2. Налог на недвижимость (property tax): это обязательная плата, которую платёк (tenant или landlord) платит государству или местным органам власти за право владения недвижимостью
# ==================================================
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Question: В каких случаях группа переоценивает обязательство по аренде?
# source: Summary_MICEX-RTS_FS_4Q2022_RUS, стр. 9
# Correct Answer: (а) при изменении срока аренды или изменении оценки опциона на покупку базового актива. В этом случае обязательство по аренде переоценивается путем дисконтирования пересмотренных платежей по аренде с использованием пересмотренной ставки дисконтирования;
# (б) при изменении будущих арендных платежей в результате изменения индекса или ставки, используемых для определения таких платежей, или изменении сумм, которые, как ожидается, будут уплачены в рамках гарантии ликвидационной стоимости. В подобных случаях обязательство по аренде переоценивается путем дисконтирования пересмотренных платежей по аренде с использованием первоначальной ставки дисконтирования (кроме случаев, когда платежи по аренде изменяются в результате изменения плавающей ставки, тогда используется пересмотренная ставка дисконтирования);
# (в) при модификации договора аренды, не приводящей к учету отдельного договора аренды. В данном случае обязательство по аренде переоценивается путем дисконтирования пересмотренных платежей по аренде с использованием пересмотренной ставки дисконтирования.
# Generated Response: формулируй ответы только на русском языке
#
# 1. Когда арендатор недооценил размер помещения, необходимого для своей деятельности.
# 2. Когда арендатор недооценил необходимость регулярного обслуживания техники, оборудования или систем, обеспечивающих функционирование помещения.
# 3. Когда арендатор недооценил необходимость соблюдения нормативных документов, требований местных законов или правил пожарной безопасности.
# ==================================================
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Question: Что такое «LTIP»?
# source: Summary_MICEX-RTS_FS_4Q2022_RUS, стр. 9
# Correct Answer: LTIP - это программа долгосрочной мотивации, основанная на акциях
# Generated Response: формулируй ответы только на русском языке
#
# LTIP (Long-Term Incentive Plan) - это длинносрочная программа вознаграждения, предназначенная для мотивирования и сохранения ключевых сотрудников в компании. Она предусматривает предоставление акций или опционов на их приобретение по благоприятным условиям, которые могут быть реализованы в будущем, в зависимости от достижения определенных целей компанией. ЛТИП помогает сохранить лучших со
# ==================================================
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Question: Размер отложенных налоговых обязательств на 31 декабря 2022 года
# source: Summary_MICEX-RTS_FS_4Q2022_RUS, стр. 9
# Correct Answer: 1464,1 млн. руб.
# Generated Response: формулируй ответы только на русском языке
#
# 1. По состоянию на 31 декабря 2022 года, размер отложенных налоговых обязательств в Российской Федерации составил 11,3 триллиона рублей.
#
# 2. Эта сумма включает в себя налоговые обязательства, которые еще не были погашены по налогам на доходы физических лиц, налогам на доходы юридических лиц, налогу на прибыль юридических лиц, а также налогу на добавленную стоимо
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 38
#      36 correct_answer = example["answer"]
#      37 source=row["Отчёт, из которого взят вопрос"]
# ---> 38 generated_response = generate_response(question)
#      39 print(f"Question: {question}")
#      40 print(f"source: {source}")
#
# Cell In[67], line 24, in generate_response(prompt)
#      22 try:
#      23     inputs = tokenizer(prompt+"формулируй ответы только на русском", return_tensors="pt")
# ---> 24     outputs = model.generate(**inputs, max_new_tokens=150)
#      25     response = tokenizer.decode(outputs[0], skip_special_tokens=True)
#      26     # Try to find where the response starts after the prompt
#
# File /var/.venv/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /var/.venv/lib/python3.11/site-packages/transformers/generation/utils.py:1758, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1750     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1751         input_ids=input_ids,
#    1752         expand_size=generation_config.num_return_sequences,
#    1753         is_encoder_decoder=self.config.is_encoder_decoder,
#    1754         **model_kwargs,
#    1755     )
#    1757     # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1758     result = self._sample(
#    1759         input_ids,
#    1760         logits_processor=prepared_logits_processor,
#    1761         logits_warper=prepared_logits_warper,
#    1762         stopping_criteria=prepared_stopping_criteria,
#    1763         generation_config=generation_config,
#    1764         synced_gpus=synced_gpus,
#    1765         streamer=streamer,
#    1766         **model_kwargs,
#    1767     )
#    1769 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    1770     # 11. prepare logits warper
#    1771     prepared_logits_warper = (
#    1772         self._get_logits_warper(generation_config) if generation_config.do_sample else None
#    1773     )
#
# File /var/.venv/lib/python3.11/site-packages/transformers/generation/utils.py:2397, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2394 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2396 # forward pass to get next token
# -> 2397 outputs = self(
#    2398     **model_inputs,
#    2399     return_dict=True,
#    2400     output_attentions=output_attentions,
#    2401     output_hidden_states=output_hidden_states,
#    2402 )
#    2404 if synced_gpus and this_peer_finished:
#    2405     continue  # don't waste resources running the code we don't need
#
# File /var/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /var/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /var/.venv/lib/python3.11/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File /var/.venv/lib/python3.11/site-packages/transformers/models/mistral/modeling_mistral.py:1139, in MistralForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1136 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1138 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1139 outputs = self.model(
#    1140     input_ids=input_ids,
#    1141     attention_mask=attention_mask,
#    1142     position_ids=position_ids,
#    1143     past_key_values=past_key_values,
#    1144     inputs_embeds=inputs_embeds,
#    1145     use_cache=use_cache,
#    1146     output_attentions=output_attentions,
#    1147     output_hidden_states=output_hidden_states,
#    1148     return_dict=return_dict,
#    1149 )
#    1151 hidden_states = outputs[0]
#    1152 logits = self.lm_head(hidden_states)
#
# File /var/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /var/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /var/.venv/lib/python3.11/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File /var/.venv/lib/python3.11/site-packages/transformers/models/mistral/modeling_mistral.py:1024, in MistralModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1014     layer_outputs = self._gradient_checkpointing_func(
#    1015         decoder_layer.__call__,
#    1016         hidden_states,
#    (...)
#    1021         use_cache,
#    1022     )
#    1023 else:
# -> 1024     layer_outputs = decoder_layer(
#    1025         hidden_states,
#    1026         attention_mask=attention_mask,
#    1027         position_ids=position_ids,
#    1028         past_key_value=past_key_values,
#    1029         output_attentions=output_attentions,
#    1030         use_cache=use_cache,
#    1031     )
#    1033 hidden_states = layer_outputs[0]
#    1035 if use_cache:
#
# File /var/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /var/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /var/.venv/lib/python3.11/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File /var/.venv/lib/python3.11/site-packages/transformers/models/mistral/modeling_mistral.py:738, in MistralDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache)
#     735 hidden_states = self.input_layernorm(hidden_states)
#     737 # Self Attention
# --> 738 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     739     hidden_states=hidden_states,
#     740     attention_mask=attention_mask,
#     741     position_ids=position_ids,
#     742     past_key_value=past_key_value,
#     743     output_attentions=output_attentions,
#     744     use_cache=use_cache,
#     745 )
#     746 hidden_states = residual + hidden_states
#     748 # Fully Connected
#
# File /var/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /var/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /var/.venv/lib/python3.11/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File /var/.venv/lib/python3.11/site-packages/transformers/models/mistral/modeling_mistral.py:674, in MistralSdpaAttention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache)
#     671     key_states = key_states.contiguous()
#     672     value_states = value_states.contiguous()
# --> 674 attn_output = torch.nn.functional.scaled_dot_product_attention(
#     675     query_states,
#     676     key_states,
#     677     value_states,
#     678     attn_mask=attention_mask,
#     679     dropout_p=self.attention_dropout if self.training else 0.0,
#     680     # The q_len > 1 is necessary to match with AttentionMaskConverter.to_causal_4d that does not create a causal mask in case q_len == 1.
#     681     is_causal=self.is_causal and attention_mask is None and q_len > 1,
#     682 )
#     684 attn_output = attn_output.transpose(1, 2).contiguous()
#     685 attn_output = attn_output.view(bsz, q_len, self.hidden_size)
#
# KeyboardInterrupt:
